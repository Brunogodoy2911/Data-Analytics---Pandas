# %% [markdown]
# <a href="https://colab.research.google.com/github/Brunogodoy2911/Data-Analytics---Pandas/blob/main/sort_values_pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
dados = {
    "Produto" : ["Maçã", "Banana", "Laranja", "Uva", "Pera"],
    "Preco" : [2.5, 3.0, 1.5, 4.0, 2.0],
    "Quantidade" : [10, 5, 8, 12, 6]
}

df = pd.DataFrame(dados)

# %%
print(df)
# Out:
#    Produto  Preco  Quantidade
# 0     Maçã    2.5          10
# 1   Banana    3.0           5
# 2  Laranja    1.5           8
# 3      Uva    4.0          12
# 4     Pera    2.0           6

# %%
# Ordenar por "Preco" em ordem crescente
df_preco = df.sort_values(by="Preco")
print(df_preco)
# Out:
#    Produto  Preco  Quantidade
# 2  Laranja    1.5           8
# 4     Pera    2.0           6
# 0     Maçã    2.5          10
# 1   Banana    3.0           5
# 3      Uva    4.0          12

# %%
# Ordenar por quantidade em ordem Decrescente
df_qtd = df.sort_values(by="Quantidade", ascending=False)
print(df_qtd)
# Out:
#    Produto  Preco  Quantidade
# 3      Uva    4.0          12
# 0     Maçã    2.5          10
# 2  Laranja    1.5           8
# 4     Pera    2.0           6
# 1   Banana    3.0           5

# %%
# Ordenação por múltiplas colunas
df_multi = df.sort_values(by=["Preco", "Quantidade"], ascending=[True, False])
print(df_multi)
# Out:
#    Produto  Preco  Quantidade
# 2  Laranja    1.5           8
# 4     Pera    2.0           6
# 0     Maçã    2.5          10
# 1   Banana    3.0           5
# 3      Uva    4.0          12
